# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pos_test_df = pd.read_csv("Test_on_day_of_result.csv", sep=" ", header=None, index_col=0, parse_dates=True)
#pos_test_df.drop(index=["I", "Antal"], inplace=True)
pos_test_df = pos_test_df[~ pos_test_df.index.isnull()]
pos_test_df.rename(columns={2:"Svardato", 3:"Prøvedato"}, inplace=True)
week_indicator = ["Ma", "Mandag"]
indicators = pos_test_df[pos_test_df[1]==week_indicator[0]]
pos_test_df.index
# Out:
# DatetimeIndex(['2020-08-31', '2020-09-01', '2020-09-02', '2020-09-03',
#                '2020-09-04', '2020-09-05', '2020-09-06', '2020-09-07',
#                '2020-09-08', '2020-09-09', '2020-09-10', '2020-09-11',
#                '2020-09-12', '2020-09-13', '2020-09-14', '2020-09-15',
#                '2020-09-16', '2020-09-17', '2020-09-18', '2020-09-19',
#                '2020-09-20', '2020-09-21', '2020-09-22', '2020-09-23',
#                '2020-09-24', '2020-09-25', '2020-09-26', '2020-09-27',
#                '2020-09-28', '2020-09-29', '2020-09-30', '2020-10-01',
#                '2020-10-02'],
#               dtype='datetime64[ns]', name=0, freq=None)

# %%
pos_test_df.plot(figsize = (15,5)) 
plt.xlabel("Dato")
plt.ylabel("Positive tests")
for i in indicators.index:
    # print(i)
    plt.axvline(i, color="green", label=week_indicator[1])
plt.legend(["Dato", "Positive tests", "Mandag"])
plt.savefig("proevesvar.pdf")
